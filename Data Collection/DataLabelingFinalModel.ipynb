# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
from collections import defaultdict
from glob import glob
from skimage import io, transform
from google.colab import drive
import string 

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Read processed dataset-
# All_Sentences.csv, generated in BaselineDataPrep

# %%
df_copy = pd.read_csv('/content/drive/MyDrive/ENGI 4800/data/All_Sentences.csv', index_col=False).dropna()[['Original_txt','AuthorsId_removed', 'punctuation_stopWord_removed','stemmed']]
m,n = df_copy.shape
df_copy.index = np.arange(m)
df_copy.columns = ['txt','AuthorsId_removed', 'punctuation_stopWord_removed','stemmed']

df_copy.info()
df = df_copy.copy().drop(['AuthorsId_removed', 'punctuation_stopWord_removed', 'stemmed'], axis=1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 90939 entries, 0 to 90938
# Data columns (total 4 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   txt                           90939 non-null  object
#  1   AuthorsId_removed             90939 non-null  object
#  2   punctuation_stopWord_removed  90939 non-null  object
#  3   stemmed                       90939 non-null  object
# dtypes: object(4)
# memory usage: 3.5+ MB

# %%
df
# Out:
#                                                      txt
# 0       #57221096756 : Conceptualization, Data - proc...
# 1      #57221100279 : Conceptualization, Data - proce...
# 2      #15841581600 : Conceptualization, revising-ori...
# 3      #55599484000 : Conceptualization, revising-ori...
# 4                             #57189246657 : Methodology
# ...                                                  ...
# 90934  #57207780605 ,  #56289147200 ,  #24781401400 ,...
# 90935   #55330051300 ,  #57203771733 , and  #70040886...
# 90936  #55330051300  and  #57203771733  collected, an...
# 90937  #57195056560 ,  #55330051300 .J. and  #7004359...
# 90938  and  #55330051300 ,  #57203771733 , and  #7004...
#
# [90939 rows x 1 columns]

# %% [markdown]
# ##Term Search -- Investigation
#
# Investigation	Conducting a research and investigation process, specifically performing the experiments, or data/evidence collection

# %%
#filter standard
df_investigation = df.loc[df.txt.str.contains('investigat',na=False) | 
                              df.txt.str.contains('research',na=False) | 
                              df.txt.str.contains('experiment',na=False) |
                              df.txt.str.contains('collect',na=False)]

# %%
df_investigation.info()
df_investigation.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 19968 entries, 7 to 90937
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   txt     19968 non-null  object
# dtypes: object(1)
# memory usage: 312.0+ KB
#                                                   txt
# 7   data collection:  #56323815300 ,  #57139150400...
# 12                    data collection:  #57208572807
# 37        investigation,  #9638921000 ,  #6602655040
# 67                conceived and designed the research
# 68                          performed the experiments

# %%
df_investigation = df_investigation.sample(n=100)
df_investigation.to_csv('/content/drive/MyDrive/ENGI 4800/data/Investigation_Matched_Sentences.csv')

# %% [markdown]
# ##Term Search -- Resources
#
# Provision of study materials, reagents, materials, patients, laboratory samples, animals, instrumentation, computing resources, or other analysis tools

# %%
df_resources = df.loc[df.txt.str.contains('material',na=False) | 
                              df.txt.str.contains('reagent',na=False) |
                              df.txt.str.contains('patient',na=False) | 
                              df.txt.str.contains('sample',na=False) |
                              df.txt.str.contains('animal',na=False) |
                              df.txt.str.contains('resource',na=False)]

# %%
df_resources.info()
df_resources.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4409 entries, 38 to 90914
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   txt     4409 non-null   object
# dtypes: object(1)
# memory usage: 68.9+ KB
#                                                    txt
# 38             resources,  #6602655040 ,  #7003331105
# 51   Furthermore, each author certifies that this m...
# 152  FVR,  #6507095734 , and  #6602003524 H generat...
# 183  #57193211235  contributed new reagents and ana...
# 229  #23029285700 ,  #7801333036 -H.,  #7004932141 ...

# %%
df_resources = df_resources.sample(n=100)
df_resources.to_csv('/content/drive/MyDrive/ENGI 4800/data/Resources_Matched_Sentences.csv')

# %% [markdown]
# ##Term Search -- Methodology
#
# Development or design of methodology; creation of models

# %%
df_methodology = df.loc[df.txt.str.contains('methodology',na=False) | 
                              df.txt.str.contains('design',na=False) |
                              df.txt.str.contains('model',na=False) |
                              df.txt.str.contains('creat',na=False) 
                              ]

# %%
df_methodology.info()
df_methodology.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14436 entries, 6 to 90935
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   txt     14436 non-null  object
# dtypes: object(1)
# memory usage: 225.6+ KB
#                                                   txt
# 6   The authors confirm contribution to the paper ...
# 11  The authors confirm contribution to the paper ...
# 33         methodology,  #6602655040 ,  #54410706100
# 46   #57190939344 ,  #55601350100 ,  #15750882000 ...
# 67                conceived and designed the research

# %%
df_methodology = df_methodology.sample(n=100)
df_methodology.to_csv('/content/drive/MyDrive/ENGI 4800/data/Methodology_Matched_Sentences.csv')

# %% [markdown]
# ## Term Search -- Visualization
# Preparation, creation and/or presentation of the published work, specifically visualization/ data presentation

# %%
df_visualization = df.loc[ df.txt.str.contains('present',na=False) &(
    df.txt.str.contains('image',na=False) |
    df.txt.str.contains('fig',na=False) |
    df.txt.str.contains('Fig',na=False) |
    df.txt.str.contains('graph',na=False) 
    
) & ~(df.txt.str.contains('data present',na=False) | df.txt.str.contains('visualiz',na=False))]
# Out:
#   File "<ipython-input-31-6c303d7aea56>", line 7
#     ) &!( df.txt.str.contains('data present',na=False) | df.txt.str.contains('visualiz',na=False))]
#        ^
# SyntaxError: invalid syntax

# %%
df_visualization.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22 entries, 1218 to 72716
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   txt     22 non-null     object
# dtypes: object(1)
# memory usage: 352.0+ bytes

# %%
# df_visualization = df_visualization.sample(n=200)
df_visualization.to_csv('/content/drive/MyDrive/ENGI 4800/data/Visualization_Sentences.csv')

# %% [markdown]
# ##Term Search -- Supervison
#
# Oversight and leadership responsibility for the research activity planning and execution, including mentorship external to the core team

# %%
#filter standard
df_supervison = df.loc[df.txt.str.contains('supervison',na=False) | 
                              df.txt.str.contains('leadership',na=False) | 
                              df.txt.str.contains('mentorship',na=False) |
                              df.txt.str.contains('oversight',na=False)]

# %%
df_supervison.info()
df_supervison.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 65 entries, 1078 to 90542
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   txt     65 non-null     object
# dtypes: object(1)
# memory usage: 1.0+ KB
#                                                     txt
# 1078  #57191055366  contributed to the study concept...
# 1365  Oversight and leadership responsibility for th...
# 1803                       He provided mentorship to Dr
# 2986   #56710978600 , conceptualization of the study...
# 2987  #57202600700 , conceptualization of the study,...

# %%
#random sampling 100
df_supervison = df_supervison.sample(n=100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-92d8f26147e8> in <module>
# ----> 1 df_supervison = df_supervison.sample(n=100)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5363             )
#    5364
# -> 5365         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    5366         result = self.take(locs, axis=axis)
#    5367         if ignore_index:
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %% [markdown]
# ##Term Search -- 	Funding acquisition
# Acquisition of the financial support for the project leading to this publication

# %%
#filter
df_funding = df.loc[df.txt.str.contains('fund',na=False) | 
                              df.txt.str.contains('financ',na=False) | 
                              df.txt.str.contains('acquisi',na=False)]

# %%
#must exclude data acquisition
df_funding = df[~df.txt.str.contains('data acquisi',na=False) ]

# %%
df_funding.info()
df_funding.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3634 entries, 19 to 90920
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   txt     3634 non-null   object
# dtypes: object(1)
# memory usage: 56.8+ KB
#                                                   txt
# 19                Funding acquisition:  #55070612500
# 45  funding acquisition,  #6602655040  All authors...
# 47  #57190939344 ,  #57210261879 ,  #57210256606 ,...
# 58   #12041802500 : Supervision, Funding acquisition.
# 75   #57219177109  and  #7003980567  acquired funding

# %%
df_funding = df_funding.sample(n=250)

# %%
df_funding.to_excel('/content/drive/MyDrive/ENGI 4800/data/label_Funding.xlsx')

# %% [markdown]
# ##Term Search -- Project administration
#
# Management and coordination responsibility for the research activity planning and execution

# %%
df_administration = df.loc[df.txt.str.contains('manage',na=False) | 
                              df.txt.str.contains('coordina',na=False) |
                              df.txt.str.contains('admin',na=False)  ]

# %%
df_administration.info()
df_administration.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2221 entries, 44 to 90870
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   txt     2221 non-null   object
# dtypes: object(1)
# memory usage: 34.7+ KB
#                                                    txt
# 44               project administration,  #6602655040
# 57   #7102338786 : Visualization, Project administr...
# 72   #6603109231  and  #7004387896  supervised and ...
# 99   Experiments were designed by  #57193928935 ,  ...
# 227   #55653401800 d.W.,  #56026483100 ,  #42462439...

# %%
df_administration = df_administration.sample(n=100)

# %%
df_supervision_administration=pd.concat([df_supervison, df_administration])

# %%
df_supervision_administration.to_excel('/content/drive/MyDrive/ENGI 4800/data/superv_admin_Matched_Sentences1.xlsx')

# %% [markdown]
# ##Term Search -- Data Curation
#
# Management activities to annotate (produce metadata), scrub data and maintain resueach data (including software code, where is its necessary for interpreting the data itself) for initial use and later re-use

# %%
df_Data_curation = df.loc[df.txt.str.contains('data curation',na=False) | 
                              df.txt.str.contains('approve',na=False) | 
                              df.txt.str.contains('supervised',na=False) |
                              df.txt.str.contains('supervision',na=False)|
                              df.txt.str.contains('produce',na=False)]

# %%
df_Data_curation.info()
df_Data_curation.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6735 entries, 10 to 90928
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   txt     6735 non-null   object
# dtypes: object(1)
# memory usage: 105.2+ KB
#                                                   txt
# 10  All authors reviewed the results and approved ...
# 15  All authors reviewed the results and approved ...
# 39  data curation,  #6602655040 ,  #55889554600 , ...
# 43                         supervision,  #6602655040
# 72  #6603109231  and  #7004387896  supervised and ...

# %%
df_Data_curation = df_Data_curation.sample(n=100)
df_Data_curation.to_csv('/content/drive/MyDrive/ENGI 4800/data/Data_curation_Matched_Sentences.csv')

# %% [markdown]
# ##Term Search -- validation
#
# Verification, whether as a part of the activity or separate, of the overall replication/reproducibility of results/ experiments and other research outputs

# %%
df_validation = df.loc[df.txt.str.contains('validation',na=False) | 
                              df.txt.str.contains('verify',na=False) |
                              df.txt.str.contains('experiment',na=False) | 
                              df.txt.str.contains('evaluation',na=False) |
                              df.txt.str.contains('experiments',na=False) |
                              df.txt.str.contains('research',na=False)]

# %%
df_validation.info()
df_validation.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16411 entries, 35 to 90937
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   txt     16411 non-null  object
# dtypes: object(1)
# memory usage: 256.4+ KB
#                                                   txt
# 35  validation,  #6602655040 ,  #54410706100 ,  #5...
# 67                conceived and designed the research
# 68                          performed the experiments
# 74   #57219177109  and  #7003980567  conceived the...
# 81  and  #16033791600  performed the experiments, ...

# %%
df_validation = df_validation.sample(n=100)
df_validation.to_csv('/content/drive/MyDrive/ENGI 4800/data/validation_Matched_Sentences.csv')
