# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from numpy.linalg import inv
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.preprocessing import OrdinalEncoder
from sklearn.svm import LinearSVC, SVC
from sklearn.metrics import accuracy_score
import nltk
import json
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#df = pd.read_csv('drive/MyDrive/ENGI 4800/author-capstone-20K-limit.csv', sep = '|', header = None).dropna()
df = pd.read_csv('drive/MyDrive/ENGI 4800/df_converted.csv',header = 0).dropna()[['pii','Converted_Section_Content','Authors']]
m,n = df.shape
df.index = np.arange(m)
df.columns = ['pii','Section_content','Authors']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16949 entries, 0 to 16948
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pii              16949 non-null  object
#  1   Section_content  16949 non-null  object
#  2   Authors          16949 non-null  object
# dtypes: object(3)
# memory usage: 529.7+ KB

# %%
df['Section_content'][1]
# Out:
# 'The authors confirm contribution to the paper as follows: study conception and design:  #57221288000 ,  #7006423551 ,  #56323815300 ; data collection:  #56323815300 ,  #57139150400 ,  #57221288000 ; analysis and interpretation of results:  #57221288000 ,  #7006423551 ; draft manuscript preparation:  #57221288000 ,  #7006423551 . All authors reviewed the results and approved the final version of the manuscript.'

# %% [markdown]
# ## Split into sentences and remove unrelated sentences

# %%
vars = ['#1','#2','#3','#4','#5','#6','#7','#8','#9', 'all', 'All', 'author', 'Author']

# %%
df_converted = df.copy()
df_converted['Sentences'] = [[] for i in range(m)]
total = 0
related = 0
for i in range(m):
  sen_lis = df['Section_content'][i].replace(';', '.').split('. ')
  for sen in sen_lis:
    total += 1
    flag = False
    for item in vars:
      if item in sen:
        flag = True
    if flag:
      df_converted['Sentences'][i].append(sen)
      related +=1
      pass
    else:
      if i<=10:
        print(sen)
        print(df['Section_content'][i])
        print(df['pii'][i])
# Out:
# Roles/Writing - original draft
#  #57189385591 , MD: Conceptualization; Roles/Writing - original draft; Formal analysis  #57213472596 , MD: Data curation  #57218421000 : Investigation; Methodology  #57213472596   #56406209000 : Roles/Writing - original draft  #57218419661  Hoti MBBS: Data Collection  #6602435498 , MD: Validation; Critical Review  #6507283777 , FRCP: Validation; Visualization David  #7006014406 , FACC: Supervision; Critical Review
# S0002914920306883
# Critical Review
#  #57189385591 , MD: Conceptualization; Roles/Writing - original draft; Formal analysis  #57213472596 , MD: Data curation  #57218421000 : Investigation; Methodology  #57213472596   #56406209000 : Roles/Writing - original draft  #57218419661  Hoti MBBS: Data Collection  #6602435498 , MD: Validation; Critical Review  #6507283777 , FRCP: Validation; Visualization David  #7006014406 , FACC: Supervision; Critical Review
# S0002914920306883

# %%
related/total
# Out:
# 0.860070291906668

# %%
df_converted['Sention_converted'] = ''
for i in range(m):
  df_converted['Sention_converted'][i] = ". ".join(df_converted['Sentences'][i])

# %%
df_converted
# Out:
#                      pii                                    Section_content  \
# 0      S0001457520316912   #57221096756 : Conceptualization, Data - proc...
# 1      S000145752031770X  The authors confirm contribution to the paper ...
# 2      S0001457521002001  The authors confirm contribution to the paper ...
# 3      S0001706X21001960  Jacques D  #7006426873  designed the study, es...
# 4      S0002914920301132  Conceptualization:  #57198261180 ,  #550706125...
# ...                  ...                                                ...
# 16944  S0024320519309415   #57196239544  conceived the work, designed an...
# 16945  S0024320520305774   #36875917900 : Conceptualization, Methodology...
# 16946  S0024320520305853   #57209316649 : Major performer, Leader #57209...
# 16947  S0024320520309747   #57218442730  performed the experiments;  #57...
# 16948  S0024320520317380   #55330051300 ,  #57203771733 , and  #70040886...
#
#                                                  Authors  \
# 0      [{Authorseq":1,"auid":57221096756,"given_name_...
# 1      [{Authorseq":1,"auid":57221288000,"given_name_...
# 2      [{Authorseq":1,"auid":57208572807,"given_name_...
# 3      [{Authorseq":1,"auid":7006426873,"given_name_p...
# 4      [{Authorseq":1,"auid":57198261180,"given_name_...
# ...                                                  ...
# 16944  [{Authorseq":1,"auid":57196239544,"given_name_...
# 16945  [{Authorseq":1,"auid":36875917900,"given_name_...
# 16946  [{Authorseq":1,"auid":57209316649,"given_name_...
# 16947  [{Authorseq":1,"auid":57218442730,"given_name_...
# 16948  [{Authorseq":1,"auid":55330051300,"given_name_...
#
#                                                Sentences  \
# 0      [ #57221096756 : Conceptualization, Data - pro...
# 1      [The authors confirm contribution to the paper...
# 2      [The authors confirm contribution to the paper...
# 3      [Jacques D  #7006426873  designed the study, e...
# 4      [Conceptualization:  #57198261180 ,  #55070612...
# ...                                                  ...
# 16944  [ #57196239544  conceived the work, designed a...
# 16945  [ #36875917900 : Conceptualization, Methodolog...
# 16946  [ #57209316649 : Major performer, Leader #5720...
# 16947  [ #57218442730  performed the experiments,  #5...
# 16948  [ #55330051300 ,  #57203771733 , and  #7004088...
#
#                                        Sention_converted
# 0       #57221096756 : Conceptualization, Data - proc...
# 1      The authors confirm contribution to the paper ...
# 2      The authors confirm contribution to the paper ...
# 3      Jacques D  #7006426873  designed the study, es...
# 4      Conceptualization:  #57198261180 ,  #550706125...
# ...                                                  ...
# 16944   #57196239544  conceived the work, designed an...
# 16945   #36875917900 : Conceptualization, Methodology...
# 16946   #57209316649 : Major performer, Leader #57209...
# 16947   #57218442730  performed the experiments.  #57...
# 16948   #55330051300 ,  #57203771733 , and  #70040886...
#
# [16949 rows x 5 columns]

# %% [markdown]
# ## Remove stop words and punctuations

# %%
from nltk.corpus import stopwords
nltk.download("stopwords",quiet=True)
stop_words = set(stopwords.words('english'))

df_copy = df.copy()

# Remove stop words
for i in range(m):
    sentence = df_converted['Sention_converted'][i].split()
    df_copy['Section_content'][i] = ' '.join([word.lower() for word in sentence if word not in stop_words and len(word)>1])

# %%
# Remove punctuations
import string
punctuations = string.punctuation

for i in range(m):
    sentence = df_copy['Section_content'][i]
    df_copy['Section_content'][i] = sentence.translate(str.maketrans('', '', string.punctuation.replace('#','')))

# %%
vocab = {}
for i in range(m):
    sentence = df_copy['Section_content'][i].split()
    for word in sentence:
        vocab[word] = vocab.get(word, 0) + 1
vocab = sorted(vocab.items(), key = lambda x: x[1], reverse = True)

# %%
vocab_top30 = vocab[0:30]
vocab_top30
# Out:
# [('data', 21283),
#  ('manuscript', 19354),
#  ('analysis', 12947),
#  ('writing', 11589),
#  ('experiments', 10814),
#  ('performed', 10313),
#  ('authors', 8291),
#  ('study', 7818),
#  ('designed', 7806),
#  ('editing', 7004),
#  ('wrote', 6917),
#  ('contributed', 6056),
#  ('all', 5992),
#  ('review', 5922),
#  ('analyzed', 5495),
#  ('design', 5426),
#  ('draft', 5051),
#  ('final', 5040),
#  ('conceptualization', 5021),
#  ('methodology', 4900),
#  ('investigation', 4823),
#  ('conceived', 4533),
#  ('interpretation', 4151),
#  ('acquisition', 4112),
#  ('supervision', 4003),
#  ('original', 3710),
#  ('project', 3510),
#  ('formal', 3368),
#  ('paper', 3358),
#  ('funding', 3214)]

# %%
df_common = pd.DataFrame(vocab_top30, columns=['common_word', 'frequency'])
df_common.plot(kind='bar', x='common_word', title='top30 common words')

# %%
vocab_size = {}
vb_length = []
for i in range(m):
    sentence = df_copy['Section_content'][i].split()
    v_s = len(set(sentence))
    vb_length.append(v_s)
    if v_s >= 115:
      print(" ".join(sentence))
    vocab_size[v_s] = vocab_size.get(v_s, 0) + 1
vocab_size = sorted(vocab_size.items(), key = lambda x: x[0], reverse = False)
# Out:
# #7005645840 #57215998279 #24766399200 s behalf as #57215998279 in group #57205176014 experimentation formal analysis data collection validation visualization writing original draft preparation reviewediting #57220204757 #57220205421 #57190871866 data analysis validation writing original draft preparation reviewediting #35516089100 #57219570837 #35516089100 #57219562717 #17134137200 #57206347055 submission isolates original draft preparation reviewediting #56204741800 writing reviewediting #7005645840 formal analysis validation original draft preparation reviewediting #57215998279 conceptualization dna analysis formal analysis validation original draft preparation reviewediting #24766399200 s conceptualization project administration formal analysis supervision validation visualization original draft preparation reviewediting the as #57215998279 in study group #6507730641 #57207999863 complejo hospitalario torrecárdenas almería #57219562717 hospital universitario puerta del mar cádiz #57216912739 #57219569029 #56204741800 de la #57216825463 #57219569190 hospital universitario reina sofía córdoba #12647674600 hospital virgen de las nieves granada #17134137200 hospital de valme sevilla #57206347055 #6601958984 hospital universitario #57529113300 servet zaragoza #6701527850 #57199695547 #57373378800 hospital universitario central de asturias oviedo #57219570837 hospital general de albacete albacete #57216825463 complejo hospitalario de toledo toledo #57219566072 #57219562655 #6506913217 hospital universitario de burgos burgos #24766399200 #57225386329 hospital río hortega valladolid #6507567904 hospital santa creu sant pau barcelona #6603608034 hospital de bellvitge barcelona #6602239815 #6701527850 #57189660027 hospital vall de hebrón barcelona #57219562717 #25121880800 hospital general de alicante alicante #55295079900 hospital general de elche elche #57219565693 #7003468500 hospital universitario la fe valencia #57529113300 hospital universitario de badajoz badajoz #17134137200 #7004382146 hospital san pedro de alcántara cáceres #6602239815 #35516089100 mayo complejo hospitalario universitario de coruña coruña #57208919816 #57219562655 ayala hospital 12 de octubre madrid #55263801200 hospital ramón cajal madrid #7005645840 #57215998279 #57219574802 #57219570837 no #55221969200 #24766399200 #35516089100 #57197746701 #57205176014 #57204216536 díaz #57219569190 #57208919816 #55263801200 núñez #7004583171 #57201071218 #56204741800 hospital general universitario gregorio marañón madrid #57373378800 #6505948743 hospital puerta de hierro madrid #35516089100 #35516089100 hospital la paz madrid #6508008231 #57190871866 del pozo #57219570158 clínica universidad de navarra pamplona #26433948200 hospital de valdecilla santander #19035348700 #57206347055 soria hospital de cruces bilbao #6508008231 #6602239815 #57022138100 #8580390600 hospital de donostia donostia #57201071218 #57188863079 #24067158400 hospital de txagorritxu vitoriagasteiz
# #16245841000 designed led fieldwork wrote full draft coordinated input coauthors acts corresponding author #23388657300 organised commissioning funding study government entity operates telehealth network geoff #7006757862 contributed manuscript important intellectual content telehealth uptake increased time still remains low developed countriesbdigitised telehealth networks offer enhanced capability remote mental health preadmission assessment treatment particularly improved visual audio qualitycinnovation diffusion theory useful approach study provider uptake new healthcare information technologieswhat study adds knowledgeaservice providers see digitised telehealth network results range relative advantages access quality mental healthcare patients rural remote areasbservice providers need support overcome challenges achieving compatibility telehealth clinical practice provider input technical administrative design rollout would reduce technical complexity improve extent technology compatible clinical practicecgreater uptake could encouraged service providers given time cost staff support use especially gps private practice this particularly important digital telehealth network challenging use traditional communication specialists different geographical locations
# please specify contribution author paper eg #6603481952 #7005397998 #6602904467 main surgeon division performed 95 360 thyroidectomies procedures thyroid follicular lesions #6603481952 main author agree accountable aspects work ensuring questions related accuracy integrity part work appropriately investigated resolved he designed original study diagnostic therapeutic flowchart finally ideated technical innovation #55513445700 made substantial contributions conception design acquisition data analysis interpretation data #56358313300 made substantial contributions conception design acquisition data analysis interpretation data #6506767930 made substantial contributions conception design acquisition data analysis interpretation data #15059751300 made substantial contributions conception design acquisition data analysis interpretation data #6603128277 director division department involved drafting manuscript revising critically important intellectual content specially given final approval version published #55513445700 one main surgeon unit performed 73 360 thyroidectomies procedures thyroid follicular lesions #7004106437 #57208337772 they main surgeon division performed 77 360 thyroidectomies procedures thyroid follicular lesions #12785508700 one main surgeon unit performed 30 360 thyroidectomies procedures thyroid follicular lesions #6602688030 main researcher nuclear medicine coordinated radiological image acquisition database controlled aspects radio guided procedures training nuclear medicine techniques checking uptake values classification #6701914044 main researcher pathology coordinated cytological histological exams controlling right acquisition methodology classification #6602233798 main researcher endocrinology coordinated endocrine aspects patients recruitment postoperative follow up giving important contribute flowchart respect
# we explored relation authors credit hisher position authorship byline using cocd algorithm part to end use allocated credit approximate contribution author made paper jung yoon 2019 generally recognized first author corresponding author normally last author make main contributions article physics the first question whether first author last author allocated higher credits authors second question position author greatest credit allocated to investigate first question classified papers several categories based number authors we chose five types papers whose number authors ranged three seven perform analyses for type paper obtain distribution first authors credit distribution last authors credit distribution authors ie authors located either first last position byline specifically papers published 2000 fig 6a shows credit distributions first authors authors similar longer thicker tails median first authors’ credit share significantly differentiate others intuitively credit distributions last authors papers published 2000 shown fig 6c longer thicker tails categories median last authors’ credit share significantly higher implies last author higher probability larger credit share authors 6b illustrates credit distribution first authors significant difference credit distribution authors categories whose quantile remarkably smaller others the results distribution comparison last authors authors 2000 fig in summary last author commonly allocated greater credit authors first author possesses smaller contribution authors papers published year 2000 in papers published year 2000 first authors authors similar contribution distributions possible reason differences contribution distribution comparisons first authors authors may that recent years first authors started junior authors to answer second question calculated credit share author paper determined position author highest credit value next obtained probability position author makes greatest contribution listed papers number authors compared results papers whose author positions randomly switched results papers published 2000 2000 demonstrate last author highest probability author greatest credit share probability first author largest credit share papers published 2000 similar rank listed authors however papers published year 2000 probability rank first author becomes dramatically low may explained fact first author young experienced research field example analyses papers five authors meanwhile papers different numbers authors exhibit similar results
electronic medical records emrs contraindications ivt based structured data•natural language processing nlp techniques received little attention management strokewhat knowledge study adds•it feasible automatically identify key information regarding ivt eligibility emrs using offtheshelf nlp tool metamap umls metathesaurus•the user experiment showed conventional emr interface clinicians could quickly extract ivtrelevant information emrs albeit many errors•by highlighting ivtrelevant information taskspecific emr interface significantly reduced errors assessing contraindications ivt might thus ensure patient safety ease workload stroke physicians•nlp techniques help extract key information regarding ivt eligibility emrs within short time thus improve quality clinical decision making

# %%
vocab_size[:10]
# Out:
# [(0, 23),
#  (1, 4),
#  (2, 8),
#  (3, 15),
#  (4, 86),
#  (5, 132),
#  (6, 150),
#  (7, 162),
#  (8, 174),
#  (9, 245)]

# %%
df_voc = pd.DataFrame(vocab_size, columns=['content_size', 'frequency'])
df_voc.plot(kind='bar', x='content_size', title='histogram of content size',figsize=(24, 5))

# %% [markdown]
# ## Stem

# %% [markdown]
# ### Use a column to store name combinations, do not stem names

# %%
"""
df_copy['Name_list'] = [[] for i in range(m)]

for i in range(m):
    tmp = df["Authors"][i][2:(-3)].replace('\\','')
    author_json_list = tmp.split('},{')
    author_json_list[0] = '"' + author_json_list[0]
    lis = []
    for item in author_json_list:
        author_dic = json.loads('{' + item + '}')
        if len(author_dic) == 1:
            continue
        elif(len(author_dic) == 3):
            lis.extend(author_dic["surname_pn"].lower().translate(str.maketrans('', '', string.punctuation)).split())
        else:
            # extract initials
            surname_lis = author_dic["surname_pn"].lower().translate(str.maketrans('', '', string.punctuation)).split()
            givenname_lis = author_dic["given_name_pn"].lower().translate(str.maketrans('', '', string.punctuation)).split()
            
            surname_initial = [item[0] for item in givenname_lis]
            givenname_initial = [item[0] for item in surname_lis]
            
            surname_initial.extend(givenname_initial)
            initials = ''.join(surname_initial)
            lis.append(initials)
            
            lis.extend(surname_lis)
            lis.extend(givenname_lis)
            lis.extend(author_dic["initials_pn"].lower().translate(str.maketrans('', '', string.punctuation)).split())
    df_copy['Name_list'][i] = lis
""";

# %%
from nltk.stem import PorterStemmer
porter = PorterStemmer()
df_stem = df_copy.copy()
for i in range(m):
    sentence = df_copy['Section_content'][i].split()
    df_stem['Section_content'][i] = ' '.join([porter.stem(word)\
                                              if not word.startswith('#')\
                                              else word\
                                              for word in sentence])

# %%
vocab_stem = {}
for i in range(m):
    sentence = df_stem['Section_content'][i].split()
    for word in sentence:
        vocab_stem[word] = vocab_stem.get(word, 0) + 1
vocab_stem = sorted(vocab_stem.items(), key = lambda x: x[1], reverse = True)

# %%
vocab_stem_top30=vocab_stem[0:30]
vocab_stem_top30
# Out:
# [('data', 21285),
#  ('manuscript', 19385),
#  ('design', 13409),
#  ('analysi', 12947),
#  ('write', 11717),
#  ('experi', 11653),
#  ('perform', 10615),
#  ('author', 9127),
#  ('studi', 8518),
#  ('review', 8244),
#  ('edit', 8238),
#  ('draft', 8077),
#  ('contribut', 7458),
#  ('wrote', 6917),
#  ('all', 5992),
#  ('supervis', 5970),
#  ('interpret', 5923),
#  ('analyz', 5655),
#  ('conceptu', 5512),
#  ('approv', 5324),
#  ('final', 5202),
#  ('investig', 5114),
#  ('methodolog', 4929),
#  ('revis', 4914),
#  ('conceiv', 4559),
#  ('acquisit', 4113),
#  ('collect', 4042),
#  ('origin', 3736),
#  ('project', 3529),
#  ('paper', 3387)]

# %%
df_common_Stem = pd.DataFrame(vocab_stem_top30, columns=['common words', 'frequency'])
df_common_Stem.plot(kind='bar', x='common words', title='Top30 Common Words after stemming')

# %%
vocab_size_stem = {}
for i in range(m):
    sentence = df_stem['Section_content'][i].split()
    v_s = len(set(sentence))
    vocab_size_stem[v_s] = vocab_size_stem.get(v_s, 0) + 1
vocab_size_stem = sorted(vocab_size_stem.items(), key = lambda x: x[0], reverse = False)

# %%
vocab_size_stem[:10]
# Out:
# [(0, 23),
#  (1, 4),
#  (2, 8),
#  (3, 15),
#  (4, 86),
#  (5, 132),
#  (6, 150),
#  (7, 165),
#  (8, 174),
#  (9, 247)]

# %%
df_voc_stem = pd.DataFrame(vocab_size_stem, columns=['content_size', 'frequency'])
df_voc_stem.plot(kind='bar', x='content_size', title='histogram of content size after stemming',figsize=(24, 5))

# %% [markdown]
# ## Removing names and initials

# %%
df_remove_name = df_stem.copy()
for i in range(m):
    sentence = df_stem['Section_content'][i].split()
    df_remove_name['Section_content'][i] = ' '.join([word for word in sentence if not word.startswith('#')])

# %%
df_remove_name
# Out:
#                      pii                                    Section_content  \
# 0      S0001457520316912  conceptu data process analysi methodolog write...
# 1      S000145752031770X  the author confirm contribut paper follow stud...
# 2      S0001457521002001  the author confirm contribut paper follow stud...
# 3      S0001706X21001960  jacqu design studi establish mp ran project wr...
# 4      S0002914920301132  conceptu data curat formal analysi fund acquis...
# ...                  ...                                                ...
# 16944  S0024320519309415  conceiv work design perform experi analyz data...
# 16945  S0024320520305774  conceptu methodolog design investig analysi vi...
# 16946  S0024320520305853                 major perform leader assist assist
# 16947  S0024320520309747  perform experi analyz data interpret result ex...
# 16948  S0024320520317380  conceiv design studi collect analyz andor inte...
#
#                                                  Authors
# 0      [{Authorseq":1,"auid":57221096756,"given_name_...
# 1      [{Authorseq":1,"auid":57221288000,"given_name_...
# 2      [{Authorseq":1,"auid":57208572807,"given_name_...
# 3      [{Authorseq":1,"auid":7006426873,"given_name_p...
# 4      [{Authorseq":1,"auid":57198261180,"given_name_...
# ...                                                  ...
# 16944  [{Authorseq":1,"auid":57196239544,"given_name_...
# 16945  [{Authorseq":1,"auid":36875917900,"given_name_...
# 16946  [{Authorseq":1,"auid":57209316649,"given_name_...
# 16947  [{Authorseq":1,"auid":57218442730,"given_name_...
# 16948  [{Authorseq":1,"auid":55330051300,"given_name_...
#
# [16949 rows x 3 columns]

# %%
vocab_remove_name = {}
for i in range(m):
    sentence = df_remove_name['Section_content'][i].split()
    for word in sentence:
        vocab_remove_name[word] = vocab_remove_name.get(word, 0) + 1
vocab_remove_name = sorted(vocab_remove_name.items(), key = lambda x: x[1], reverse = True)

# %%
vocab_re_top30=vocab_remove_name [0:30]
vocab_remove_name [0:30]
# Out:
# [('data', 21285),
#  ('manuscript', 19385),
#  ('design', 13409),
#  ('analysi', 12947),
#  ('write', 11717),
#  ('experi', 11653),
#  ('perform', 10615),
#  ('author', 9127),
#  ('studi', 8518),
#  ('review', 8244),
#  ('edit', 8238),
#  ('draft', 8077),
#  ('contribut', 7458),
#  ('wrote', 6917),
#  ('all', 5992),
#  ('supervis', 5970),
#  ('interpret', 5923),
#  ('analyz', 5655),
#  ('conceptu', 5512),
#  ('approv', 5324),
#  ('final', 5202),
#  ('investig', 5114),
#  ('methodolog', 4929),
#  ('revis', 4914),
#  ('conceiv', 4559),
#  ('acquisit', 4113),
#  ('collect', 4042),
#  ('origin', 3736),
#  ('project', 3529),
#  ('paper', 3387)]

# %%
df_common_re = pd.DataFrame(vocab_re_top30, columns=['common words', 'frequency'])
df_common_re.plot(kind='bar', x='common words', title='TOP 30 Common Words after removing author names')

# %%
vocab_size_remove_name = {}
for i in range(m):
    sentence = df_remove_name['Section_content'][i].split()
    v_s = len(set(sentence))
    vocab_size_remove_name[v_s] = vocab_size_remove_name.get(v_s, 0) + 1
vocab_size_remove_name = sorted(vocab_size_remove_name.items(), key = lambda x: x[0], reverse = False)

# %%
df_voc_re = pd.DataFrame(vocab_size_remove_name, columns=['content_size', 'frequency'])
df_voc_re.plot(kind='bar', x='content_size', title='histogram of content size after removing author names',figsize=(24, 5))

# %% [markdown]
# ## Correlation between vocab size and author counts

# %%
vocab_length = []
sentence_length = []
author_count = []
for i in range(m):
    sentence = df_remove_name['Section_content'][i].split()
    vocab_length.append(len(set(sentence)))
    sentence_length.append(len(sentence))
    author_count.append(df_remove_name['Authors'][i].count('auid'))

# %%
import scipy
print('Correlation between author count and vocab size',scipy.stats.pearsonr(vocab_length,author_count)[0])
print('Correlation between author count and content length',scipy.stats.pearsonr(sentence_length,author_count)[0])
# Out:
# Correlation between author count and vocab size 0.09688921156618897
# Correlation between author count and content length 0.0892683921548921

# %%
vocab_length, sentence_length, author_count = np.array(vocab_length), np.array(sentence_length), np.array(author_count)

# %%
lb = 10
ub = 100
scipy.stats.pearsonr(vocab_length[(vocab_length>lb) & (vocab_length<ub)], author_count[(vocab_length>lb) & (vocab_length<ub)])[0]
# Out:
# 0.08105969859385612

# %%
lb = 20
ub = 500
scipy.stats.pearsonr(sentence_length[(sentence_length>lb) & (sentence_length<ub)], author_count[(sentence_length>lb) & (sentence_length<ub)])[0]
# Out:
# 0.0577203894087028

# %% [markdown]
# ## Create a dictionary of work contribution for each article

# %%
df_converted['Contributions'] = [{} for i in range(m)]
for i in range(2,3):
  sentence_lis = df_converted['Sentences'][i]
  for sen in sentence_lis:
    sen_converted = sen.translate(str.maketrans('', '', string.punctuation.replace('#','')))
    word_list = sen_converted.split()
    contribution_list = []
    author_list = []
    for word in word_list:
      if word.startswith('#') or word.lower() == 'all':
        author_list.append(word)
      else:
        if word.lower() != 'and': 
          contribution_list.append(word)
    df_converted['Contributions'][i][" ".join(contribution_list)] = author_list

# %%
df_converted['Contributions'][2]
# Out:
# {'The authors confirm contribution to the paper as follows study conception design': ['#57208572807',
#   '#26645222600'],
#  'data collection': ['#57208572807'],
#  'analysis interpretation of results': ['#57208572807', '#26645222600'],
#  'draft manuscript preparation': ['#57208572807', '#26645222600'],
#  'authors reviewed the results approved the final version of the manuscript': ['All']}
